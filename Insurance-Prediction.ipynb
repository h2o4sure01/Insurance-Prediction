# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('train_data.csv')

# %%
train.head()
# Out:
#   Customer Id  YearOfObservation  Insured_Period  Residential  \
# 0      H14663               2013             1.0            0
# 1       H2037               2015             1.0            0
# 2       H3802               2014             1.0            0
# 3       H3834               2013             1.0            0
# 4       H5053               2014             1.0            0
#
#   Building_Painted Building_Fenced Garden Settlement  Building Dimension  \
# 0                N               V      V          U               290.0
# 1                V               N      O          R               490.0
# 2                N               V      V          U               595.0
# 3                V               V      V          U              2840.0
# 4                V               N      O          R               680.0
#
#    Building_Type  Date_of_Occupancy NumberOfWindows Geo_Code  Claim
# 0              1             1960.0               .     1053      0
# ...

# %%
train.shape
# Out:
# (7160, 14)

# %%
train.isnull().any()
# Out:
# Customer Id           False
# YearOfObservation     False
# Insured_Period        False
# Residential           False
# Building_Painted      False
# Building_Fenced       False
# Garden                 True
# Settlement            False
# Building Dimension     True
# Building_Type         False
# Date_of_Occupancy      True
# NumberOfWindows       False
# Geo_Code               True
# Claim                 False
# dtype: bool

# %%
train.drop(['Geo_Code','Building Dimension','Garden','Customer Id'],1, inplace=True)

# %%
train.head()
# Out:
#    YearOfObservation  Insured_Period  Residential Building_Painted  \
# 0               2013             1.0            0                N
# 1               2015             1.0            0                V
# 2               2014             1.0            0                N
# 3               2013             1.0            0                V
# 4               2014             1.0            0                V
#
#   Building_Fenced Settlement  Building_Type  Date_of_Occupancy  \
# 0               V          U              1             1960.0
# 1               N          R              1             1850.0
# 2               V          U              1             1960.0
# 3               V          U              1             1960.0
# 4               N          R              1             1800.0
#
#   NumberOfWindows  Claim
# 0               .      0
# 1               4      0
# 2               .      0
# 3               .      0
# 4               3      0
